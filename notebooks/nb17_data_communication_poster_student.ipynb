# %% [markdown]
# # Elements of Data Communication and Poster Design
#
# <hr>
#
# <center>
# <div>
# <img src="https://raw.githubusercontent.com/davi-moreira/2026Summer_predictive_analytics_purdue_MGMT474/main/notebooks/figures/mgmt_474_ai_logo_02-modified.png" width="200"/>
# </div>
# </center>
#
# # <center><a class="tocSkip"></center>
# # <center>QM47400 Predictive Analytics</center>
# # <center>Professor: Davi Moreira </center>
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/davi-moreira/2026Summer_predictive_analytics_purdue_MGMT474/blob/main/notebooks/nb17_data_communication_poster_student.ipynb)
#
# ---

# %% [markdown]
# > **📋 Participation Reminder:** This notebook contains **2 PAUSE-AND-DO exercises**. Complete both before submitting your notebook.
#
# ---

# %% [markdown]
# ## Learning Objectives
#
# By the end of this notebook, you will be able to:
#
# 1. Apply the **Six Principles of Data Communication** (context, visualization, less-is-more, hierarchy, beauty, story) to a predictive-analytics project figure.
# 2. Diagnose common chart failures (misleading scales, dual axes, pie-chart abuse) and rebuild the same data into a clearer view.
# 3. Increase the **data-ink ratio** of a busy chart by removing borders, gridlines, redundant points, and decorative color.
# 4. Plan the **layout, typography, and visual hierarchy** of a research-conference poster aimed at a non-expert audience.
# 5. Draft a poster **abstract and section outline** that turns your group's predictive-analytics work into a story a reader can follow in 90 seconds.
#
# ---

# %% [markdown]
# ## Why This Matters
#
# > *"Nothing in life is more important than the ability to communicate effectively."*
# > Attributed to Gerald R. Ford
#
# You have spent the entire course building a leakage-safe pipeline, picking baselines, tuning hyperparameters, locking the test set, opening it once for a single verdict, and probing your final model for fairness. The work is real. The next days decide whether anyone outside your group ever sees it.
#
# The audience for your final poster (judges, faculty, recruiters wandering through the conference) will spend **about ninety seconds** in front of your work before they decide whether to lean in or move on. They will not read your code. They will not run your notebook. They will read three things, in this order: your **title**, your **best chart**, and one **sentence from the abstract**. If those three reveal a clear question, a clean answer, and a number they can defend repeating, you win the next two minutes of their attention. If they reveal a busy chart with twelve colors and a five-line caption, you do not.
#
# This notebook is your conversion engine. The first half teaches the principles of clean visual communication; the second half walks the architecture of a research-conference poster section by section. By the end of today, you will have audited at least one figure from your project, planned the eleven sections of your poster, and drafted the single most-read paragraph in the whole submission: the abstract.
#
# > **A question that often comes up here:** *"do these design principles actually change how my work lands, or is this just aesthetics?"* Communication is not decoration layered on top of good analysis; it is the channel through which the analysis reaches anyone at all. A decision-maker who cannot quickly see what you found, why it matters, and how confident you are will act as if the finding never existed, no matter how rigorous the model behind it. The clearest result in the world changes nothing if the person who controls the budget, the staffing, or the next experiment walks away confused. So treat the design half of this work the way you treated the cross-validation half: as something you measure against and refine, not a flourish you add at the end. A sharp, honest chart paired with one defensible sentence moves a real decision further than a marginal gain in accuracy that no one outside your group will ever read about.
#
# ---

# %% [markdown]
# ## 1. The Forest and the Trees
#
# You have spent recent days deep in implementation details: preprocessing pipelines, fold splits, calibration curves, slice-level fairness reports. Yesterday in notebook 16 you built forecasting models with walk-forward validation. Today the camera pulls back. The question is no longer *"is this model technically right?"* but *"is this story technically right and **legible**?"*
#
# The shift matters more than it sounds. A model that predicts churn with 0.87 ROC-AUC is worthless to a retention manager who cannot tell, from your poster, which customers to call first. A regression that cuts pricing error by \$12,000 per property is worthless to a CFO who cannot find that number on your poster in thirty seconds. The model was the hard part. Making the model visible is today's work.

# %% [markdown]
# <center>
# <img src="https://github.com/davi-moreira/2026Summer_predictive_analytics_purdue_MGMT474/blob/main/notebooks/figures/floresta.jpg?raw=1" width="35%"/>
# <br><em>Step back from the trees long enough to see the forest.</em>
# </center>

# %% [markdown]
# Every analysis has a purpose. Today's work is about making sure that purpose survives the trip from your code into a stranger's head in under ninety seconds.
#
# > **A question that often comes up here:** *"why split the design lecture out from the modeling lectures? Couldn't I learn this incrementally?"* In practice, no. Communication choices that look harmless in the middle of a notebook (a chart with three y-axes, a table with eleven columns, a caption that says "see code for details") become expensive when they are the **only** thing the audience sees. Pulling back to think about the whole forest (what stays, what gets cut, what becomes the headline) is much harder once the poster is half-built. So we do it before.
#
# ---

# %% [markdown]
# ## 2. The Six Principles of Data Communication
#
# Every section that follows maps to one principle. Treat them as a checklist you can run a chart against:
#
# | # | Principle | The question it asks |
# |---|---|---|
# | 1 | **Context Matters** | *Compared to what?* What baseline turns this number into evidence? |
# | 2 | **Visualization Derives From Data** | *What kind of data is this?* What chart respects its shape? |
# | 3 | **Less Is More: Separate Signal From Noise** | *What can I delete and still understand the chart?* |
# | 4 | **Hierarchy Among Data** | *Where does the eye land first? Should it?* |
# | 5 | **Beauty Counts: Not All Data Are Equally Important** | *Which one number am I asking the reader to remember?* |
# | 6 | **Telling Your Story** | *Can a non-expert restate the conclusion in one sentence?* |
#
# Section 3 starts with the first principle and works through them in order, ending with a worked example that applies all six to a single chart. Then Section 9 onward walks the same audit through the architecture of a poster.
#
# ---

# %% [markdown]
# ## 3. Context Matters
#
# Every analysis has a goal and an audience. Three rules follow:
#
# - **Separate exploration from final analysis.** Resist the temptation to show everything you did. The reader did not ask for your debugging history.
# - **Adapt the report to the audience.** Decision-makers rarely care about execution details. They care about the decision the number supports.
# - **Keep one specific learning objective in mind.** It tells you which information is relevant and which is filler.
#
# Isolated numbers say very little. To support evidence-based decisions, an appropriate **basis for comparison** has to be established up front. *"Revenue rose 12%"* means nothing without a peer group, a prior period, or a forecast next to it.

# %% [markdown]
# ### 3.1 Context Can Come From New Information…

# %% [markdown]
# <center>
# <img src="https://github.com/davi-moreira/2026Summer_predictive_analytics_purdue_MGMT474/blob/main/notebooks/figures/contexto-add.png?raw=1" width="55%"/>
# <br><em>A single number gains meaning when a benchmark is placed beside it.</em>
# </center>

# %% [markdown]
# ### 3.2 …or Reinforce Existing Information

# %% [markdown]
# <center>
# <img src="https://github.com/davi-moreira/2026Summer_predictive_analytics_purdue_MGMT474/blob/main/notebooks/figures/contexto-obs.png?raw=1" width="55%"/>
# <br><em>Sometimes the comparison is to the audience's own prior expectation.</em>
# </center>

# %% [markdown]
# > **A question that often comes up here:** *"what counts as a fair benchmark on a poster?"* For your final poster, the most useful benchmarks are the **baselines from notebook 03 / notebook 09** (your own dummy model or simple linear/logistic regression) and any **published number** in the field if one exists. Reporting your tuned model's ROC-AUC alone is hard to interpret; reporting it next to your baseline ROC-AUC turns it into a lift number a judge can defend.
#
# ---

# %% [markdown]
# ## 4. Visualization Derives From Data
#
# Before you choose a chart, ask three questions about the data behind it:
#
# 1. **What type of data is this?** Categorical, ordered, continuous, time-indexed?
# 2. **How many dimensions are you encoding?** One? Two? Three or more?
# 3. **Where will the chart be consumed?** Most reports, and every conference poster, are consumed in 2D from three feet away. Encoding more than two dimensions on a static page usually confuses the reader.
#
# And one rule that overrides all three: **be careful with scales.** A bad axis can flip the conclusion of a chart without changing the underlying data.

# %% [markdown]
# ### 4.1 Use Graphs Instead of Tables
#
# The next two images show identical data: once as a table of numbers, once as a bar chart. Before scrolling down, ask yourself which format lets you extract the comparison in less time. The answer drives a design rule you will use on every poster figure.

# %% [markdown]
# <center>
# <img src="https://github.com/davi-moreira/2026Summer_predictive_analytics_purdue_MGMT474/blob/main/notebooks/figures/table_vs_plot.png?raw=1" width="75%"/>
# <br><em>The table technically contains the answer. The plot reveals it at a glance.</em>
# </center>

# %% [markdown]
# <center>
# <img src="https://github.com/davi-moreira/2026Summer_predictive_analytics_purdue_MGMT474/blob/main/notebooks/figures/table_vs_plot_02.png?raw=1" width="75%"/>
# <br><em>Same numbers, two encodings: the chart wins on every reader.</em>
# </center>

# %% [markdown]
# When the relationship between numbers is comparative or trend-based, a chart usually beats a table. Reserve tables for cases where readers need to **look up specific values**, not interpret a pattern. *(Source: Kastellec & Leoni, 2007, "Using Graphs Instead of Tables in Political Science.")*
#
# ---

# %% [markdown]
# ### 4.2 Scales Can Be Misleading
#
# A truncated y-axis is the single most common chart failure in business presentations. The image below starts its y-axis well above zero, turning a modest percentage-point difference into what looks like a dramatic swing. A CFO who sees this chart in a quarterly review will make a different decision than a CFO who sees the same data on a zero-based axis.

# %% [markdown]
# <center>
# <img src="https://github.com/davi-moreira/2026Summer_predictive_analytics_purdue_MGMT474/blob/main/notebooks/figures/escala-fail.PNG?raw=1" width="60%"/>
# <br><em>Truncated y-axes turn a 3-point swing into a visual landslide.</em>
# </center>

# %% [markdown]
# For poster figures, default to **axes that start at zero** for any quantity where zero is a meaningful reference (counts, percentages, currency). When a non-zero baseline is justified (for example, a tightly clustered time series), say so explicitly in the caption.
#
# ---

# %% [markdown]
# ### 4.3 Avoid Dual Axes
#
# Dual-axis charts appear in boardroom slide decks more often than in any other setting, and they mislead in every one. When two series share an x-axis but each gets its own y-axis, the visual alignment between the two lines is controlled by whoever chose the axis ranges, not by the data.

# %% [markdown]
# <center>
# <img src="https://github.com/davi-moreira/2026Summer_predictive_analytics_purdue_MGMT474/blob/main/notebooks/figures/eixo-duplo.png?raw=1" width="55%"/>
# <br><em>Two y-axes invite the eye to read causation that the data does not support.</em>
# </center>

# %% [markdown]
# ### 4.4 …And Triple Axes
#
# If dual axes strain the reader's ability to hold two scales in their head, triple axes abandon it entirely. The image below is real, and if you find yourself reaching for a third axis, it is a signal that one chart is trying to tell three stories at once. Split it into three panels.

# %% [markdown]
# <center>
# <img src="https://github.com/davi-moreira/2026Summer_predictive_analytics_purdue_MGMT474/blob/main/notebooks/figures/eixo-triplo.png?raw=1" width="60%"/>
# <br><em>If two axes were a stretch, three are a magic trick.</em>
# </center>

# %% [markdown]
# Dual-axis charts force the reader to mentally align two scales. When the alignment is arbitrary (and it almost always is), the chart hides as much as it reveals. Prefer **two side-by-side panels** with a shared x-axis, or **standardize both series** (e.g., to z-scores or percent-change-from-baseline) and overlay them on a single shared axis.
#
# ---

# %% [markdown]
# ### 4.5 Fewer Pie Charts
#
# The pie chart is the default choice for "show me a breakdown," and it is almost always the wrong one. The reason is perceptual: the human eye estimates lengths far more accurately than angles or areas. The image below shows the same data as a pie chart and a bar chart side by side: notice how much faster you can rank the categories in the bar version.

# %% [markdown]
# <center>
# <img src="https://github.com/davi-moreira/2026Summer_predictive_analytics_purdue_MGMT474/blob/main/notebooks/figures/pie-vs-bar.png?raw=1" width="82%"/>
# <br><em>The pie chart asks the reader to compare angles. The bar chart asks them to compare lengths. Lengths win.</em>
# </center>

# %% [markdown]
# ### 4.6 When 3D Distorts the Comparison
#
# Sometimes the chart type is defensible but the *rendering* sabotages it. The image below is a three-dimensional pie chart Steve Jobs presented at the **Macworld 2008** keynote to show U.S. smartphone market share by brand. The intent was persuasive: convince the audience (technology media who would introduce the iPhone to buyers considering a switch to Apple, and retailers deciding whether to stock it) that the iPhone 3G had become a serious contender, landing in **third place at 19.5%**. The chart does deliver that headline. But three design choices quietly distort the very comparison it asks the reader to make.

# %% [markdown]
# <center><img src="https://github.com/davi-moreira/2026Summer_predictive_analytics_purdue_MGMT474/blob/main/notebooks/figures/steve-jobs-pie.jpg?raw=1" width="72%"/><br><em>Steve Jobs presents U.S. smartphone market share at Macworld 2008. The 3D tilt inflates the slices nearest the viewer. Source: <a href="https://www.engadget.com/2008-01-15-live-from-macworld-2008-steve-jobs-keynote.html">Engadget, Live from Macworld 2008: Steve Jobs keynote</a>.</em></center>
#
# **What this teaches:** the format is forgivable (a pie *can* show a few brands splitting a whole), but the execution introduces three separate distortions.
#
# First, the **3D effect misleads the eye about rank.** The chart is tilted so the bottom of the pie sits visually closer to the viewer than the top, which inflates the apparent area of the lower slices. The iPhone's green slice ends up looking larger than the slice actually ahead of it, nudging the audience to read the iPhone as *second* place when the numbers put it third. There is no analytical reason to add the third dimension here; its only effect is to flatter the product.
#
# Second, the **slices carry numbers but no category labels.** To learn which product each wedge represents, the reader has to bounce between the wedge and a separate legend, and even then the pie makes the comparison hard. The headline gap is small: third place is 19.5% and second place is 21.2%, a 1.7-point difference that translates into nearly identical angles. A pie can communicate a *large* difference at a glance, but it is the wrong tool for distinguishing two nearly equal shares.
#
# Third, **nothing in the chart encodes the ranking.** The wedges are not ordered ascending or descending, there is no color scale to signal magnitude, and even the legend is left unsorted. The reader is handed the pieces of an ordered comparison without any of the visual cues that would let them see the order.
#
# The fix is structural, not cosmetic: replace the pie with a **horizontal bar chart ordered by share**, with each brand labeled directly at its bar. Lengths along a common axis make a 1.7-point gap legible, and direct labels remove the legend round-trip entirely.

# %% [markdown]
# > **A question that often comes up here:** *"is the pie chart really banned?"* Not banned, but reserve it for the rare case of **two or three categories that sum to a meaningful whole**, where the headline is the overall split rather than a fine comparison between slices. For anything else (especially anything ordered or anything with more than three categories) a horizontal bar chart will outperform a pie chart on every reader test we have ever run in this course.
#
# ---

# %% [markdown]
# ### 4.7 Check Potential Ideas: The Python and R Graph Galleries

# %% [markdown]
# Before you build a custom figure from scratch, scroll the galleries. Both are filterable by chart type; both link to the source code that produced each figure.
#
# <center>
# <img src="https://github.com/davi-moreira/2026Summer_predictive_analytics_purdue_MGMT474/blob/main/notebooks/figures/python-logo.png?raw=1" width="100"/>
# <br><a href="https://python-graph-gallery.com/"><strong>The Python Graph Gallery</strong></a>
# </center>
#
# <center>
# <img src="https://github.com/davi-moreira/2026Summer_predictive_analytics_purdue_MGMT474/blob/main/notebooks/figures/r-logo.svg?raw=1" width="100"/>
# <br><a href="https://r-graph-gallery.com/"><strong>The R Graph Gallery</strong></a>
# </center>
#
# When you find a chart you like, copy the **structure** (encoding, layout, annotation strategy), then redraw it with your own data and your own labels. Verbatim copies are rarely the right answer, but informed mimicry is faster than designing from scratch.
#
# ---

# %% [markdown]
# ## 5. Less Is More: Separate Signal From Noise
#
# The more visual elements your chart contains, the higher the **cognitive load** on the reader. Every line, label, gridline, and decoration is a small tax. Your job is to lower that tax.
#
# This is what Edward Tufte called the **data-ink ratio**:
#
# $$\text{Data-Ink Ratio} = \frac{\text{Data-Ink}}{\text{Total ink used to print the graphic}}$$
#
# The numerator is the ink that *encodes data*. The denominator is everything you printed. Your goal is to push the ratio toward 1.0 by deleting any ink that does not encode data, and only that ink.
#
# The next nine sub-sections walk a single bar chart through a **seven-step cleanup**, removing one piece of non-data ink at a time. Watch what happens at each step: the underlying numbers never change, but the chart's signal grows louder as the noise around it falls away. By the time we reach the "before and after" panel in §5.9, the same data tells a much clearer story.

# %% [markdown]
# ### 5.1 The Data-Ink Ratio in One Picture

# %% [markdown]
# <center>
# <img src="https://github.com/davi-moreira/2026Summer_predictive_analytics_purdue_MGMT474/blob/main/notebooks/figures/data-ink.png?raw=1" width="82%"/>
# <br><em>Same chart, same data: every step removes non-data ink without losing information.</em>
# </center>

# %% [markdown]
# The next eight panels walk one chart through the cleanup, one decision at a time. Watch what gets deleted at each step and ask whether anything *the reader needs* is being lost.

# %% [markdown]
# ### 5.2 Step 1: Starting Point
#
# This is what a default analytics tool gives you out of the box: every border, gridline, point marker, and axis label turned on at once. Nothing here is wrong; the chart is technically accurate. But together these elements compete for attention, and no single element wins. The reader's eye bounces instead of landing.

# %% [markdown]
# <center>
# <img src="https://github.com/davi-moreira/2026Summer_predictive_analytics_purdue_MGMT474/blob/main/notebooks/figures/limpeza-1.PNG?raw=1" width="65%"/>
# <br><em>Default chart from a typical analytics tool: borders, gridlines, points, redundant labels.</em>
# </center>

# %% [markdown]
# ### 5.3 Step 2: Eliminate the Border
#
# The border marks the edge of the plot area, but the axis lines and data points already define that boundary. Removing it is the cheapest cleanup: zero information lost, one layer of visual noise gone. In matplotlib: `ax.spines['top'].set_visible(False)` and the same for the right spine.

# %% [markdown]
# <center>
# <img src="https://github.com/davi-moreira/2026Summer_predictive_analytics_purdue_MGMT474/blob/main/notebooks/figures/limpeza-2.PNG?raw=1" width="65%"/>
# <br><em>The frame around the plot encodes nothing. Delete.</em>
# </center>

# %% [markdown]
# ### 5.4 Step 3: Clean the Gridlines
#
# Gridlines help when readers need to read exact values off the y-axis. On a poster, the story is almost always about a trend or a comparison, not about precise readoffs. Heavy gridlines compete with the data lines for the reader's attention. Lighten them to a pale grey, reduce their number, or remove them entirely.

# %% [markdown]
# <center>
# <img src="https://github.com/davi-moreira/2026Summer_predictive_analytics_purdue_MGMT474/blob/main/notebooks/figures/limpeza-3.PNG?raw=1" width="65%"/>
# <br><em>Heavy gridlines compete with the data. Lighten or remove.</em>
# </center>

# %% [markdown]
# ### 5.5 Step 4: Remove the Points
#
# When a continuous line carries the story, the individual data markers are redundant ink. Every dot restates information the line already conveys. Removing them lets the trend speak without interruption, and frees up visual bandwidth for the annotation you will add in Section 8.

# %% [markdown]
# <center>
# <img src="https://github.com/davi-moreira/2026Summer_predictive_analytics_purdue_MGMT474/blob/main/notebooks/figures/limpeza-4.PNG?raw=1" width="65%"/>
# <br><em>When the line is the message, the dots are redundant ink.</em>
# </center>

# %% [markdown]
# ### 5.6 Step 5: Process the Axes
#
# Long tick labels ("January 2024," "February 2024") force the reader to parse dates instead of reading the chart. Shortening or thinning the ticks, and dropping axis lines that carry no information, reduces the cognitive load without sacrificing precision. The rule of thumb: if a tick label is longer than the gap between ticks, it is too long.

# %% [markdown]
# <center>
# <img src="https://github.com/davi-moreira/2026Summer_predictive_analytics_purdue_MGMT474/blob/main/notebooks/figures/limpeza-5.PNG?raw=1" width="65%"/>
# <br><em>Strip overlong tick labels, reduce label density, drop axis lines that are not load-bearing.</em>
# </center>

# %% [markdown]
# ### 5.7 Step 6: Adjust the Label
#
# A y-axis label that floats far from the data forces the reader's eye to leave the chart to understand what the numbers mean. Moving the label close to the data it describes (or, better, integrating the unit into the title) cuts that bounce. Every bounce is a moment the reader might lose interest.

# %% [markdown]
# <center>
# <img src="https://github.com/davi-moreira/2026Summer_predictive_analytics_purdue_MGMT474/blob/main/notebooks/figures/limpeza-6.PNG?raw=1" width="65%"/>
# <br><em>Move the title and units close to the data they describe.</em>
# </center>

# %% [markdown]
# ### 5.8 Step 7: Adjust Colors
#
# Decorative color draws the eye to the palette, not to the pattern. A single mid-saturation hue says "this is the data line" without competing for attention. Save the bright accent color for later; Section 6 will show you where to spend it for maximum impact.

# %% [markdown]
# <center>
# <img src="https://github.com/davi-moreira/2026Summer_predictive_analytics_purdue_MGMT474/blob/main/notebooks/figures/limpeza-7.PNG?raw=1" width="65%"/>
# <br><em>Replace decorative color with a single mid-saturation hue.</em>
# </center>

# %% [markdown]
# ### 5.9 Before and After
#
# Same data, same chart type, same number of pixels on the screen. The version on the right delivers its message in roughly half the time, because every remaining element earns its place. That is the goal for every figure on your poster.

# %% [markdown]
# <center>
# <img src="https://github.com/davi-moreira/2026Summer_predictive_analytics_purdue_MGMT474/blob/main/notebooks/figures/limpeza-8.PNG?raw=1" width="92%"/>
# <br><em>Same data, same dimensions, same number of pixels: much higher data-ink ratio.</em>
# </center>

# %% [markdown]
# **Synthesizing the seven steps.** The cleanup did three things, in order: (i) deleted ink that encoded nothing: borders and gridlines; (ii) replaced redundant ink: points behind bars, axes that repeated the labels; (iii) chose colors and labels that earned their place. Each step is small. Together they double the data-ink ratio without losing a single number.
#
# > **A question that often comes up here:** *“isn’t a stripped-down chart cold or boring?”* It is the opposite. The more non-data ink you remove, the more visually loud the **remaining** ink becomes. The before/after pair above does not lose information; it amplifies the signal that was already there. The chart on the right is what your poster should look like.
#
# A clean chart is the starting point. The next question: of the ink that remains, what does the reader look at first?
#
# ---

# %% [markdown]
# > 🤔 **Quick check, your own figure:** Open one figure from your Milestone 02 or Milestone 03 work. List two pieces of non-data ink you could delete without losing information. Keep your answer in mind; Exercise 1 will ask you to do this formally.

# %% [markdown]
# ### 5.10 The Same Cleanup in Code (Optional)
#
# The eight-step walkthrough above is visual. The cell below applies the same principles in matplotlib, the tool you will use to rebuild your project figures. Run it to see the default output and the cleaned-up version side by side.

# %%
# (Optional) Applying the data-ink cleanup in matplotlib
import matplotlib.pyplot as plt
import numpy as np

models = ['Baseline', 'LogReg', 'Random Forest', 'XGBoost']
roc_auc = [0.50, 0.81, 0.85, 0.87]

fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# Left panel: default matplotlib
axes[0].bar(models, roc_auc, color='steelblue')
axes[0].set_title('Default matplotlib output')
axes[0].set_ylabel('ROC-AUC (5-fold CV)')
axes[0].set_ylim(0, 1.0)

# Right panel: data-ink cleanup applied
ax = axes[1]
colors = ['#cccccc', '#cccccc', '#cccccc', '#e07b39']
ax.bar(models, roc_auc, color=colors, edgecolor='none')
ax.set_title('XGBoost leads the field at 0.87 ROC-AUC',
             fontsize=11, fontweight='bold', loc='left', pad=12)
ax.set_ylabel('ROC-AUC (5-fold CV)')
ax.set_ylim(0, 1.0)

for spine in ['top', 'right', 'left']:
    ax.spines[spine].set_visible(False)
ax.tick_params(left=False)

# Direct label on champion bar
ax.text(3, 0.89, '0.87', ha='center', fontweight='bold',
        fontsize=12, color='#e07b39')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 6. Hierarchy Among Data
#
# Once you have a clean chart, you have to choose **what the reader looks at first**. That is hierarchy. The eye is not democratic; it lands on whatever is loudest. Your job is to make the loudest thing the *right* thing.
#
# On a poster viewed from three feet away, hierarchy is the difference between a judge who spots your headline number in five seconds and a judge who gives up after ten. The next exercise demonstrates the principle with a task you can feel.

# %% [markdown]
# ### 6.1 Count the Number 3s
#
# Try this: scan the image below and count how many times the digit 3 appears. Time yourself; you will likely need ten seconds or more, and you will not be confident in your answer.

# %% [markdown]
# <center>
# <img src="https://github.com/davi-moreira/2026Summer_predictive_analytics_purdue_MGMT474/blob/main/notebooks/figures/hierarquia-1.PNG?raw=1" width="70%"/>
# <br><em>Try to count how many 3s appear in this block of digits.</em>
# </center>

# %% [markdown]
# ### 6.2 Now Try Again: With Hierarchy
#
# Same digits, one visual change. Notice how the task collapses from a ten-second search to a two-second scan. That is hierarchy at work, and that is exactly what happens when a judge scans your poster.

# %% [markdown]
# <center>
# <img src="https://github.com/davi-moreira/2026Summer_predictive_analytics_purdue_MGMT474/blob/main/notebooks/figures/hierarquia-2.PNG?raw=1" width="70%"/>
# <br><em>Same digits, one visual change. The 3s become countable in seconds.</em>
# </center>

# %% [markdown]
# Hierarchy works because the reader's eye **filters before it counts**. The same idea drives every good poster figure: the headline number should be visually **louder** than every other element, by a factor large enough that you can spot it from across a room. If you remember nothing else from this section, remember this: the reader will look at the loudest thing on your chart whether you designed it that way or not. You are not choosing whether hierarchy exists; you are choosing whether you control it.
#
# ---

# %% [markdown]
# ### 6.3 Ways to Draw Attention
#
# Six dials let you push one element to the top: **size** (bigger wins), **weight** (bold wins), **color** (saturated wins), **contrast** (high wins), **position** (top-left wins in Western reading order), and **isolation** (surrounded by whitespace wins). The image below demonstrates all six.

# %% [markdown]
# <center>
# <img src="https://github.com/davi-moreira/2026Summer_predictive_analytics_purdue_MGMT474/blob/main/notebooks/figures/hierarquia-3.PNG?raw=1" width="78%"/>
# <br><em>Size, weight, color, contrast, position, isolation: six dials you can turn to put one element on top.</em>
# </center>

# %% [markdown]
# ### 6.4 Highlighting With Color
#
# Of the six dials, color is the one you will reach for most often on a poster; it is the cheapest hierarchy move available. A single accent color over a muted base palette redirects the reader's eye as effectively as doubling the font size, at zero cost in layout space.

# %% [markdown]
# <center>
# <img src="https://github.com/davi-moreira/2026Summer_predictive_analytics_purdue_MGMT474/blob/main/notebooks/figures/h-cores.PNG?raw=1" width="78%"/>
# <br><em>Single accent color over a muted base: the cheapest hierarchy you will ever buy.</em>
# </center>

# %% [markdown]
# ### 6.5 Returning to Our Cleaned-Up Chart
#
# The cleaned-up chart from Section 5 is correct and clear, but it has no hierarchy; every series competes for attention equally. The two images below show what happens when you add one accent color and one annotation. The chart goes from "accurate" to "persuasive."

# %% [markdown]
# <center>
# <img src="https://github.com/davi-moreira/2026Summer_predictive_analytics_purdue_MGMT474/blob/main/notebooks/figures/limpeza-9.PNG?raw=1" width="78%"/>
# <br><em>Same clean chart from Section 5, now with one series highlighted.</em>
# </center>

# %% [markdown]
# <center>
# <img src="https://github.com/davi-moreira/2026Summer_predictive_analytics_purdue_MGMT474/blob/main/notebooks/figures/limpeza-10.PNG?raw=1" width="78%"/>
# <br><em>And here with a second hierarchy layer: annotation pointing the eye to the headline number.</em>
# </center>

# %% [markdown]
# ### 6.6 Use Colors Strategically
#
# Most categorical color palettes include one saturated accent and several muted tones. Spend the accent on the thing you want the reader to remember. If you have spent it on three different elements, none of them is the accent anymore.

# %% [markdown]
# <center>
# <img src="https://github.com/davi-moreira/2026Summer_predictive_analytics_purdue_MGMT474/blob/main/notebooks/figures/cores.PNG?raw=1" width="82%"/>
# <br><em>Most categorical color palettes have one accent and several greys. Spend the accent on the thing you want remembered.</em>
# </center>

# %% [markdown]
# > **A question that often comes up here:** *"how many colors should a poster figure have?"* For headline figures: **two**. One muted base color (greys, light blues) for everything that is context, and **one** accent color for the number you want the reader to walk away with. If a chart has more than three colors, ask whether each one is doing structural work, and if it isn't, pick the first three and grey out the rest.
#
# ---

# %% [markdown]
# > 🤔 **Quick check: where does the eye land?** Open your best project figure. Where does your eye land first? Is that the element you want the reader to remember? If not, which single change (size, color, or annotation) would redirect it?
# >
# > Hierarchy decides what is loudest. The next section asks: is the chart pleasant enough that the reader stays long enough to hear the message?

# %% [markdown]
# ## 7. Beauty Counts: Not All Data Are Equally Important
#
# Hierarchy chooses what is loudest. Beauty makes the chart pleasant enough that the reader **stays** long enough to hear the message. The two work together: a hierarchical chart that is ugly still loses readers; they flinch away before the data registers. A beautiful chart with no hierarchy buries its point under polish; the reader enjoys the look but walks away without a number.
#
# Beauty in data visualization is not decoration. It is the set of choices (alignment, whitespace, typeface, color temperature) that signal competence and reduce cognitive friction. A well-designed chart tells the reader "this team took the work seriously" before a single number is read. On a research-poster floor where judges evaluate ninety submissions in an afternoon, that signal earns an extra fifteen seconds of attention, which is often the difference between a glance and a conversation.

# %% [markdown]
# ### 7.1 Emphasizing the Main Point
#
# The image below shows a generic bar chart on the left and an emphasized version on the right. The emphasized version uses size and color to put one bar on top; the rest of the chart recedes into context. The reader walks away remembering one number, not four.

# %% [markdown]
# <center>
# <img src="https://github.com/davi-moreira/2026Summer_predictive_analytics_purdue_MGMT474/blob/main/notebooks/figures/enfase.PNG?raw=1" width="75%"/>
# <br><em>The 'after' panel uses size and color to put one bar on top; the rest of the chart melts into context.</em>
# </center>

# %% [markdown]
# ### 7.2 Same Idea, Side by Side
#
# The two charts below show a comparison without emphasis and the same comparison with emphasis. Watch how the second version collapses the reading task from "compare all four bars" to "read the highlighted one and note the gap."

# %% [markdown]
# <center>
# <img src="https://github.com/davi-moreira/2026Summer_predictive_analytics_purdue_MGMT474/blob/main/notebooks/figures/enfase-2.PNG?raw=1" width="75%"/>
# <br><em>Without emphasis: every bar competes for the same attention.</em>
# </center>
#
# <center>
# <img src="https://github.com/davi-moreira/2026Summer_predictive_analytics_purdue_MGMT474/blob/main/notebooks/figures/enfase-3.PNG?raw=1" width="75%"/>
# <br><em>With emphasis: one bar, one accent color, one number remembered.</em>
# </center>

# %% [markdown]
# The two charts above contain identical numbers. The right-hand version converts a generic comparison into a one-sentence takeaway by burning **size + color** on a single bar. That one-sentence-takeaway test is the standard your poster figures will be measured against.
#
# > **A question that often comes up here:** *“can I use my school’s colors on the poster?”* Absolutely. Purdue’s Old Gold and black make a strong one-accent palette. The rule is not “avoid brand colors” but “spend the accent on one element.” If every bar, heading, and border is Old Gold, nothing stands out. Pick one element (the headline bar, the title banner, or the key series) and let it carry the brand. Everything else stays neutral.
#
# ---

# %% [markdown]
# > 🤔 **Quick check, the one-bar test:** Think of the single number your poster needs the reader to remember. Is there a figure in your current work that makes that number visually louder than everything around it? If not, which bar, line, or cell would you burn the accent color on?
# >
# > Clean ink, clear hierarchy, a palette that earns dwell time: five principles in place. The final principle ties them together: every figure tells a specific story.

# %% [markdown]
# ## 8. Telling Your Story
#
# The final principle is the one that ties the previous five together. A clean chart with good hierarchy and a tasteful palette still has to tell a **specific** story: a beginning, a middle, and a number the reader walks away with.
#
# The sections below walk a single chart through improvement steps. By the end, the chart is no longer a chart but a **story**.

# %% [markdown]
# ### 8.1 Start From the Default Chart

# %% [markdown]
# <center>
# <img src="https://github.com/davi-moreira/2026Summer_predictive_analytics_purdue_MGMT474/blob/main/notebooks/figures/final-1.PNG?raw=1" width="70%"/>
# <br><em>What is this chart telling you? Honest answer: nothing in particular yet.</em>
# </center>

# %% [markdown]
# ### 8.2 Let's Clean

# %% [markdown]
# <center>
# <img src="https://github.com/davi-moreira/2026Summer_predictive_analytics_purdue_MGMT474/blob/main/notebooks/figures/final-2.PNG?raw=1" width="70%"/>
# </center>

# %% [markdown]
# ### 8.3 Highlight the Story Element

# %% [markdown]
# <center>
# <img src="https://github.com/davi-moreira/2026Summer_predictive_analytics_purdue_MGMT474/blob/main/notebooks/figures/final-3.PNG?raw=1" width="70%"/>
# </center>

# %% [markdown]
# ### 8.4 Are We Using the Right Plot?

# %% [markdown]
# <center>
# <img src="https://github.com/davi-moreira/2026Summer_predictive_analytics_purdue_MGMT474/blob/main/notebooks/figures/final-4.PNG?raw=1" width="70%"/>
# </center>

# %% [markdown]
# ### 8.5 Now We Have a Time Series!

# %% [markdown]
# <center>
# <img src="https://github.com/davi-moreira/2026Summer_predictive_analytics_purdue_MGMT474/blob/main/notebooks/figures/final-5.PNG?raw=1" width="70%"/>
# </center>

# %% [markdown]
# ### 8.6 Final Narrative

# %% [markdown]
# <center><img src="https://github.com/davi-moreira/2026Summer_predictive_analytics_purdue_MGMT474/blob/main/notebooks/figures/hist-1.PNG?raw=1" width="78%"/><br><em>Step 1</em></center>

# %% [markdown]
# <center><img src="https://github.com/davi-moreira/2026Summer_predictive_analytics_purdue_MGMT474/blob/main/notebooks/figures/hist-2.PNG?raw=1" width="78%"/><br><em>Step 2</em></center>

# %% [markdown]
# <center><img src="https://github.com/davi-moreira/2026Summer_predictive_analytics_purdue_MGMT474/blob/main/notebooks/figures/hist-3.PNG?raw=1" width="78%"/><br><em>Step 3</em></center>

# %% [markdown]
# <center><img src="https://github.com/davi-moreira/2026Summer_predictive_analytics_purdue_MGMT474/blob/main/notebooks/figures/hist-4.PNG?raw=1" width="78%"/><br><em>Step 4</em></center>

# %% [markdown]
# <center><img src="https://github.com/davi-moreira/2026Summer_predictive_analytics_purdue_MGMT474/blob/main/notebooks/figures/hist-5.PNG?raw=1" width="78%"/><br><em>Step 5</em></center>

# %% [markdown]
# <center><img src="https://github.com/davi-moreira/2026Summer_predictive_analytics_purdue_MGMT474/blob/main/notebooks/figures/hist-6.PNG?raw=1" width="78%"/><br><em>Step 6</em></center>

# %% [markdown]
# <center><img src="https://github.com/davi-moreira/2026Summer_predictive_analytics_purdue_MGMT474/blob/main/notebooks/figures/hist-7.PNG?raw=1" width="78%"/><br><em>Step 7</em></center>

# %% [markdown]
# <center><img src="https://github.com/davi-moreira/2026Summer_predictive_analytics_purdue_MGMT474/blob/main/notebooks/figures/hist-8.PNG?raw=1" width="78%"/><br><em>Step 8</em></center>

# %% [markdown]
# <center><img src="https://github.com/davi-moreira/2026Summer_predictive_analytics_purdue_MGMT474/blob/main/notebooks/figures/hist-9.PNG?raw=1" width="92%"/><br><em>Before and after: same numbers, transformed reading experience.</em></center>

# %% [markdown]
# ## 📝 PAUSE-AND-DO Exercise 1: Audit One Project Figure (8 minutes)
#
# **Task:** Pick **one figure** from your group's current Milestone 02 / Milestone 03 work: a confusion matrix, a calibration curve, a feature-importance bar chart, anything you would consider putting on the final poster. Audit it against the six principles.
#
# **Instructions:**
#
# 1. Paste or sketch the figure into the cell below (a screenshot pasted into a markdown image link is fine for this exercise).
# 2. For each of the six principles, write **one sentence** answering:
#    - **Context:** What benchmark or comparison is on the chart? (If none, what should be added?)
#    - **Visualization:** Is the chart type the right shape for the data? Could a simpler chart make the same point?
#    - **Less Is More:** What ink could you delete (border, gridlines, redundant labels) without losing information?
#    - **Hierarchy:** Where does the eye land first? Where *should* it land?
#    - **Beauty:** How many colors does the chart use? Could you cut to two (muted base + one accent)?
#    - **Story:** Cover the chart and ask: what one-sentence conclusion should a reader walk away with? Is the chart delivering that sentence?
# 3. Write a one-paragraph **rebuild plan**: which two or three changes you will make before the figure goes on the poster.
#
# ---
#
# > 💡 **Gemini Prompt:** "I am auditing a [chart type] from my predictive-analytics project. The chart shows [variables] for the goal of [analysis goal]. Walk me through the six principles of data communication (context, visualization, less-is-more, hierarchy, beauty, story) and tell me, for each principle, the one most likely improvement I should make. End with a three-bullet rebuild plan I can apply before putting this figure on a research poster."
# >
# > **After running, verify:**
# > - [ ] Each of the six principles has a concrete suggestion (not a generic "make it clearer")
# > - [ ] At least one suggestion targets ink-deletion (gridlines, borders, redundant labels)
# > - [ ] At least one suggestion targets hierarchy (size, color, annotation)
# > - [ ] The rebuild plan has exactly three bullets, each one a single change you can make in 10 minutes
#
# ---

# %%
print("## Correlation Heatmap Audit")
print("")
print("### 1. Context: Compared to what?")
print("   **Improvement:** Emphasize the target variable (`layoff_rate_pct`) by explicitly labeling its row/column as the primary focus, perhaps with a different background color or thicker border, providing immediate context for the correlations that matter most for predicting layoffs.")
print("")
print("### 2. Visualization: What kind of data is this? What chart respects its shape?")
print("   **Improvement:** Ensure a divergent color scale is used (e.g., red for strong positive, blue for strong negative, white/light gray for near-zero) to clearly distinguish between positive and negative correlations and their strengths at a glance, as this best respects the continuous and bi-directional nature of correlation data.")
print("")
print("### 3. Less Is More: What can I delete and still understand the chart?")
print("   **Improvement:** Remove redundant numerical correlation values from inside the heatmap cells if the color intensity already conveys the magnitude sufficiently. If crucial, only annotate the most significant correlations to reduce clutter and increase the data-ink ratio.")
print("")
print("### 4. Hierarchy: Where does the eye land first? Should it?")
print("   **Improvement:** Reorder the variables so that `layoff_rate_pct` is the first or last row/column. This draws the eye immediately to its correlations with all other variables, establishing a clear hierarchy of importance for your prediction goal.")
print("")
print("### 5. Beauty: Not all data are equally important.")
print("   **Improvement:** Use a color palette that is perceptually uniform and accessible (e.g., colorblind-friendly), with a single accent color reserved for highlighting the cells representing the strongest correlations with `layoff_rate_pct`, letting these key relationships stand out.")
print("")
print("### 6. Story: Can a non-expert restate the conclusion in one sentence?")
print("   **Improvement:** Add a concise title and a short caption that directly state the one-sentence conclusion about which variables are most strongly correlated with mass layoffs based on your heatmap findings. For example: 'Revenue and new hires show the strongest correlation with layoff rates.'")
print("")
print("## Three-Bullet Rebuild Plan:")
print("1.  **Reorder and Highlight:** Sort the variables in the heatmap to place `layoff_rate_pct` prominently (first or last), and apply a distinct visual highlight (e.g., a bold border or specific accent color) to its row/column to guide the reader's focus.")
print("2.  **Simplify Color and Labels:** Refine the color scale to be clearly divergent (positive/negative) and remove all numerical correlation values from within the cells, allowing color intensity to be the primary indicator of correlation strength.")
print("3.  **Annotate Key Findings:** Add direct annotations or text labels to the 2-3 strongest correlations with `layoff_rate_pct` (e.g., 'Strong positive correlation', 'Strong negative correlation') to explicitly state the main takeaways, and ensure the chart title communicates the core story.")

# %% [markdown]
# ![Screenshot 2026-06-09 at 6.58.13 PM.png](data:image/png;base64,...)

# %% [markdown]
# ### YOUR FINDINGS HERE:
#
# **Figure I am auditing:** _(Correlation Heatmap Milestone 2, Screenshot link is directly above this cell)_
#
# **1. Context:** _(The target variable, layoff_rate_pct is shown in the bottom left and right and is mildly influenced as a few variables whether positively or negatively as shown in the graph ranging from -0.18 to 0.09)
#
# **2. Visualization:** _(The heatpmap ranges from dark red to light blue with red showing a very high correlation and light blue refers to the lowest value of correlation)_
#
# **3. Less Is More:** _(We could delete a few other variables that show very little correlation to the target variable such as employees_start with a correlation of 0.01)_
#
# **4. Hierarchy:** _(The eye lands first on the top right with the darker red colors then slowly drags down to the bottom with some dark blue values.)_
#
# **5. Beauty:** _(I think the color scheme could've been adjusted to be more visualy appealing and directs the viewer towards the target variable more)_
#
# **6. Story:** _(Add a concise title and a short caption that directly state the one-sentence conclusion about which variables are most strongly correlated with mass layoffs based on your heatmap findings)_
#
# **Rebuild plan (3 bullets):**
#
# 1. _(Reorder the variables so the target variable is on top)_
# 2. _(Change the color scheme to direct the user towards the target variable first)_
# 3. _(Annotate key findings clearly)_
#
# ---

# %% [markdown]
# ## 9. Why a Poster Presentation?
#
# The principles above apply to any analytics deliverable: a Jupyter notebook, a Slack message, an executive slide. From here on, we narrow the focus to the specific Final Project deliverable: a single poster, designed for an Undergraduate Research Conference.

# %% [markdown]
# <center>
# <img src="https://github.com/davi-moreira/2026Summer_predictive_analytics_purdue_MGMT474/blob/main/notebooks/figures/project-history.jpg?raw=1" width="55%"/>
# </center>
#
# A research poster does five things at once:
#
# - **Showcases your group’s work** in a single static frame any reader can scan
# - **Organizes your ideas and results** into the eleven-section architecture used by every academic field
# - **Is visually appealing** enough that strangers stop walking past it
# - **Encourages interactive discussion**: the poster is a conversation starter, not the conversation itself
# - **Demonstrates your mastery** of predictive-analytics concepts in a form non-specialists can evaluate

# %% [markdown]
# **Why this list is the spec, not just a description.** The first three items are about the *deliverable*: what the poster has to be. The last two are about the *audience*: what the poster has to do for a reader who cannot ask questions. A conference-floor reader cannot scroll back, cannot ask you to clarify, and will not stay if the opening thirty seconds fail. Every later section in this notebook addresses one of those five constraints.

# %% [markdown]
# > **A question that often comes up here:** *"why a poster instead of a slide deck or a written report?"* Posters are the conference-research format precisely **because** they force the constraints we have been training against in this notebook: single page, three-foot reading distance, ninety-second attention budget, no presenter required (the poster has to defend itself even when nobody is standing next to it). Slide decks let you hide behind narration. Written reports let you hide behind length. A poster forces you to commit.
#
# ---

# %% [markdown]
# ## 10. Designing a Predictive Analytics Poster: Objectives
#
# Before you place a single text block, lock the **three things** the poster has to communicate. These three items are not optional, and they are not interchangeable. They follow a sequence that mirrors the way a non-expert reads evidence, and violating that sequence is the fastest way to lose your reader.

# %% [markdown]
# <center>
# <img src="https://github.com/davi-moreira/2026Summer_predictive_analytics_purdue_MGMT474/blob/main/notebooks/figures/paper-abstract.jpg?raw=1" width="55%"/>
# </center>
#
# 1. **Communicate the key findings and impact** of your project: the one number a stranger should remember.
# 2. **Highlight the predictive approach**, the methodology, and any novel insight.
# 3. **Highlight the business implications**: translate your model output into the decision a stakeholder can now make differently.
#
# If any of those three is unclear to your group right now, the poster is not yet ready to be designed. Stop and align in writing first; the next sections assume the answers exist.

# %% [markdown]
# **Notice the sequence: finding → method → implication.** A poster that opens with the model architecture before naming the problem loses the reader who does not yet know why they should care. A poster that lists the business implication before showing the evidence loses credibility; the reader has nothing to anchor the claim to. The order is not negotiable, even on a single 36×48 inch panel; the eye reads top-to-bottom and judges read in that order.

# %% [markdown]
# ---

# %% [markdown]
# ## 11. Planning Your Poster: Template and Rubric
#
# The course provides a starter template and an official rubric for the URC live-presentation evaluation. The rubric Milestone 04 will use to grade your final submission lives inside the milestone document and is **separate** from the URC live-judging rubric below, but the criteria overlap heavily, so reading both is the highest-leverage thing you can do in the next twenty minutes.

# %% [markdown]
# <center>
# <img src="https://github.com/davi-moreira/2026Summer_predictive_analytics_purdue_MGMT474/blob/main/notebooks/figures/poster_template.png?raw=1" width="68%"/>
# <br><em>Course poster template, used by every group on this course.</em>
# </center>

# %% [markdown]
# **Resources:**
#
# - **Course poster template (.pptx):** Please refer to the assignment instructions on the course Brightspace page.
# - **URC live-presentation rubric:** [Purdue URC Rubric](https://www.purdue.edu/undergrad-research/conferences/spring/Rubric_Poster.pdf)
# - **Walkthrough video:** [Designing a research poster](https://www.youtube.com/watch?v=ReN-QcVTZ1o)
# - **Past course posters:** [Professor Moreira's mentored projects gallery](https://davi-moreira.github.io/applied_projects.html)
#
# > Thanks to [Professor Matthew A. Lanham](https://matthewalanham.github.io/experiential-learning.html) for sharing the original version of this template.
#
# > *The URC rubric above is what the conference judges use to evaluate live presentations. For grading on this course, your group's poster will be evaluated against the rubric inside Milestone 04: read both.*
#
# ---

# %% [markdown]
# ## 12. Planning Your Poster: Visual Hierarchy and Layout
#
# A poster has hierarchy at **three layers**: the layout (what is where), the typography (what is loudest), and the content (what is most important). All three have to agree, and they fail independently.
#
# Think of it this way: a beautifully typeset poster with a single-column layout buries the headline below the fold. A three-column poster with inconsistent fonts makes the reader re-calibrate their eye on every section. And a clean layout with consistent fonts but unfocused content gives the reader nothing to remember. Your job is to get all three layers pulling in the same direction.

# %% [markdown]
# <center>
# <img src="https://github.com/davi-moreira/2026Summer_predictive_analytics_purdue_MGMT474/blob/main/notebooks/figures/poster_template.png?raw=1" width="68%"/>
# <br><em>Course poster template: three-column layout with clear visual hierarchy.</em>
# </center>
#
# - Provide a visually engaging, **easy-to-navigate** summary.
# - **Always lay out in columns**, typically three for a 36×48 inch poster.
# - **Headings:** Large and bold, in a consistent hierarchy that guides the reader.
# - **Color and contrast:** Pick a simple palette (one accent + neutrals) that highlights the main points without competing with your figures.
# - **Font size:** Body text should be legible from **three feet away**; that is the test, not “looks fine on my laptop screen”.
# - **Flow:** Logical reading order, top-left to bottom-right.

# %% [markdown]
# **The three layers fail independently.** Great content with a one-column layout buries the headline. A three-column layout with inconsistent fonts forces the reader's eye to keep recalibrating. Clean layout and consistent typography but unfocused content gives the reader nothing to remember. Audit each layer separately: print a thumbnail at 25% scale and check whether the headline, the method, and the recommendation are visible in under 10 seconds. If not, one of the three layers is failing, usually typography first, content second, layout third.

# %% [markdown]
# ### Layout and Design Guidelines
#
# The guidelines below are the mechanical decisions (spacing, font sizes, color counts) that implement the three-layer hierarchy above. Treat them as defaults you can adjust, not rules you cannot break. But if you break one, know which layer of hierarchy you are affecting.

# %% [markdown]
# **Keep it simple**
#
# - Limit text and rely on **figures, charts, and bullet points**.
# - Use consistent **color schemes**, fonts, and alignment.
# - Use a **QR code** to drive your audience to a dashboard, project webpage, or live demo.
#
# **Use of space**
#
# - **White space is your friend**: avoid clutter.
# - Group related sections in boxes or visually distinct areas.
# - Aim for roughly **60% graphics / 40% text**.
#
# **Key text guidelines**
#
# - **Title:** \~85–100 pt
# - **Headings / Subheadings:** \~46–55 pt
# - **Body Text:** \~34–38 pt
# - **Captions:** \~26–28 pt
# - All of the above must be readable from three feet away.

# %% [markdown]
# ---

# %% [markdown]
# ## 13. Planning Your Poster: Organizing Your Content
#
# Every research poster, regardless of field, follows roughly the same eleven-section architecture. The architecture is not arbitrary; it mirrors the way a trained reader evaluates evidence: context first (why should I care?), method second (why should I believe you?), result third (what did you find?), implication last (what should I do about it?). Adapt this list to your project; most groups will compress sections 6–8 and expand section 9, because the business implication is where judges spend the most time.

# %% [markdown]
# <table>
# <tr><th>#</th><th>Section</th><th>What goes here</th></tr>
# <tr><td>1</td><td><strong>Title and Authors</strong></td><td>Clear, concise, visible from across the room. Plus the four group members + course + advisor.</td></tr>
# <tr><td>2</td><td><strong>Abstract / Introduction</strong></td><td>One paragraph: <em>why the problem matters + what the main result is</em>.</td></tr>
# <tr><td>3</td><td><strong>Business Problem</strong></td><td>What is the project goal in stakeholder language?</td></tr>
# <tr><td>4</td><td><strong>Analytics Problem Framing</strong></td><td>What you aim to predict or explain, and why this is the right framing.</td></tr>
# <tr><td>5</td><td><strong>Research Question</strong></td><td>One sentence summarizing your project as a question you will answer.</td></tr>
# <tr><td>6</td><td><strong>Data and EDA</strong></td><td>Key variables, sample size, key descriptive plot.</td></tr>
# <tr><td>7</td><td><strong>Methodology</strong></td><td>Modeling approach focused on the response variable. Include the leakage-safe pipeline diagram.</td></tr>
# <tr><td>8</td><td><strong>Model Building and Evaluation</strong></td><td>Cross-validation results, baseline comparison, the locked-test-set verdict.</td></tr>
# <tr><td>9</td><td><strong>Business Implication</strong></td><td>Validation of the model in stakeholder terms: what decision changes.</td></tr>
# <tr><td>10</td><td><strong>Conclusion and Future Work</strong></td><td>Wrap-up + potential next steps.</td></tr>
# <tr><td>11</td><td><strong>Acknowledgments and References</strong></td><td>Recognize collaborators and cite data sources / libraries.</td></tr>
# </table>
#
# > **A question that often comes up here:** *"can I drop a section if my project doesn't need it?"* Yes, if you can defend the omission to a judge in one sentence. The most common defensible cut is collapsing **Research Question** (section 5) into **Analytics Problem Framing** (section 4) when the two phrasings are nearly identical. The most common indefensible cut is dropping **Acknowledgments and References** because you "ran out of room" ; that signals a layout problem, not a content problem.
#
# ---

# %% [markdown]
# ### The Research Design Flow
#
# The seven-step flow below maps the logical skeleton of every predictive-analytics project. Either embed a small version of this diagram on your poster, or use its seven steps as the organizing spine for your Methods and Results sections.

# %% [markdown]
# <center>
# <img src="https://github.com/davi-moreira/2026Summer_predictive_analytics_purdue_MGMT474/blob/main/notebooks/figures/research_design_flow.jpg?raw=1" width="75%"/>
# <br><em>The seven-step research-design flow: problem → question → data → method → model → evaluation → implication. Either show this diagram on your poster or use the seven steps as your section headers under Methodology.</em>
# </center>

# %% [markdown]
# > **A question that often comes up here:** *"do I have to draw this exact diagram on my poster?"* No, but the **flow** has to be visible. Either embed a small version of the diagram above, or use its seven steps as the bullet points under your Methodology section. What you cannot do is skip the flow and hope the reader reconstructs it from the section headings alone.
#
# ---

# %% [markdown]
# ## 14. Designing for Predictive Analytics: The Special Case
#
# Most poster advice is the same for every field, whether the project sits in biology, engineering, or economics. This section is about what changes *because* your project is a modeling project. These are the details a judge who knows predictive analytics looks for first, and they fall into two groups: how you **report your model's performance**, and how you **show that your evaluation was honest**.

# %% [markdown]
# **Reporting performance: three things judges look for.**
#
# First, **name your model in plain text.** Write "logistic regression," "random forest," or "gradient boosting" somewhere obvious. Do not make the reader reverse-engineer the method from the metrics.
#
# Second, **report the headline metric with its confidence interval, not a lone number.** A confidence interval is the range your score would likely land in if you ran the study again, and you already computed it with cross-validation back in notebook 08. A judge who sees "ROC-AUC = 0.87" with nothing next to it reads it as overclaiming. "ROC-AUC = 0.87 (95% CI 0.84 to 0.90)" reads as careful work.
#
# Third, **show the top three to five features** that drove the predictions. A horizontal bar chart of feature importance is the right shape, because the reader can scan the ranking from top to bottom without tilting their head.
#
# **Proving the work is honest: two more things.**
#
# Fourth, **label every axis, and put labels directly on the chart** instead of in a separate legend when you have four or fewer lines or bars. The reader is three feet away, not three inches, so the hierarchy and storytelling ideas from Sections 6 and 8 matter even more here.
#
# Fifth, **show your train/test split as a picture.** A small pipeline diagram, or even a simple flow arrow, makes clear that your evaluation never peeked at the test data. Judges trained in analytics look for this the way an auditor looks for the independence note in a financial statement: it is the signal that the numbers can be trusted.

# %% [markdown]
# **The two mistakes that hurt analytics posters most.** The first is reporting a single number with no confidence interval, which reads as overclaiming. The second is hiding the baseline, which lets the judge assume your model barely beats a coin flip, because you never showed what you were beating. Both are quick fixes: the confidence interval came out of notebook 08, the baseline came out of notebook 09, and the rubric gives you visible credit for showing them.
#
# > **A question that often comes up here:** *"why do judges care so much about the confidence interval and the baseline?"* Because together they answer the only two questions a skeptical reader really has: "is this result real, or did you just get lucky on one split?" and "is it actually better than the obvious, do-nothing option?" The confidence interval answers the first by showing how much your score wobbles from fold to fold; the baseline answers the second by giving the judge something to compare against. A strong score with no interval and no baseline looks like a claim with no evidence behind it, no matter how good the number is.

# %% [markdown]
# ---

# %% [markdown]
# ## 15. Crafting a Clear Narrative
#
# The poster is the medium. The story is the thing. Two reminders before you start writing: one about *tone*, one about *discipline*.

# %% [markdown]
# <center>
# <img src="https://github.com/davi-moreira/2026Summer_predictive_analytics_purdue_MGMT474/blob/main/notebooks/figures/how-to-write-good-02.png?raw=1" width="45%"/>
# <br><em>Writing rules that fit on one page apply to your poster too: short sentences, active voice, concrete nouns.</em>
# </center>

# %% [markdown]
# **Why these "rules for writing well" survive every decade.** Short sentences, active voice, concrete nouns, no jargon the reader does not already share. A poster amplifies the cost of breaking them: every adjective competes for the reader's 90-second budget, and every nominalization makes a sentence one read-through longer.

# %% [markdown]
# <center>
# <img src="https://github.com/davi-moreira/2026Summer_predictive_analytics_purdue_MGMT474/blob/main/notebooks/figures/thesis_word_count_02.gif?raw=1" width="68%"/>
# <br><em>The academic-writing trap: word-count optimization. Avoid it. Your poster has fewer than 600 words. Make every one earn its place.</em>
# </center>

# %% [markdown]
# **The Introduction and “So What?” framing is what separates “a project I did” from “a recommendation a stakeholder can act on.”** Spend more time editing these two paragraphs than any equation on the poster; they decide whether the next reader stops or walks past. A test that catches weak openers: cover everything except the Introduction and ask a teammate who has not seen the poster to summarize, in one sentence, what your group did and why it matters. If they cannot, rewrite.
#
# > **A question that often comes up here:** *“how do I write the abstract if my results are not final yet?”* Draft it now with the numbers you have; even if they shift by a point or two, the structure will not. The five-sentence skeleton (problem, data, method, headline number, business implication) is stable as soon as your champion model is chosen. Updating a number takes thirty seconds; restructuring a paragraph you never wrote takes an hour on deadline night.
#
# ---

# %% [markdown]
# ---

# %% [markdown]
# ## 16. Effective Figures and Tables on a Poster
#
# Everything you learned in Sections 3 through 8 applies here, with one catch: a poster is read from three feet away, on the first try, with no second chances. Your reader cannot squint at a tiny axis label. They cannot hover over a point for a tooltip. They cannot scroll back to re-read a caption. So every figure has to land at arm's length, the first time someone looks at it.

# %% [markdown]
# For **charts and graphs**, three rules do most of the work.
#
# First, **label every axis.** An unlabeled axis is a question the reader has to answer before they can even begin reading your chart.
#
# Second, **use one accent color** for the data that makes your point, and let everything else fade to grey. The reader's eye should travel straight to the story.
#
# Third, **write captions that state the conclusion, not the topic.** "XGBoost beats the baseline by 8 points of ROC-AUC" tells the reader what to think. "ROC-AUC comparison across models" just repeats the axis label and wastes the space.
#
# For **tables**, there is one test: could a chart make the same point faster? If yes, use the chart. A table earns its place only when the reader needs to look up an exact value. A small comparison table (four rows, three columns) can work, and so can a confusion matrix with one cell highlighted. But a table with eleven rows and eight columns belongs in your analysis notebook, not on a poster a judge reads in ninety seconds.

# %% [markdown]
# **Make it big enough to read across a room.** On a poster, figure labels should be at least 24 pt and captions at least 18 pt. Here is the test: print one figure at full size, tape it to the wall, and step back three feet. If you cannot read the axis label from there, neither can the judge.
#
# > **A question that often comes up here:** *"how many figures should the poster have?"* Three to five is the sweet spot. Aim for one headline figure that captures the main result (your cross-validation comparison chart, or the confusion matrix with the key cell highlighted), one method figure (the pipeline diagram, or a simple picture of how you split the data), and one diagnostic figure (a calibration plot, a feature-importance bar chart, or an error breakdown by customer segment). Past five figures, they start fighting each other for attention, which is the same hierarchy problem from Section 6, now scaled up to the whole poster.

# %% [markdown]
# **Extend the poster beyond the wall with a QR code.** A poster holds about 600 words and a handful of figures, but your project is bigger than that. A QR code is the small square barcode anyone can scan with a phone camera to open a web link in seconds. Print one in a corner of the poster and you hand curious readers a door to everything that did not fit: an interactive dashboard, a live demo app, your project's code repository, a short video walkthrough, or the full analysis notebook. You can even point it at your team's LinkedIn pages, so a recruiter who liked your work can connect with you before they walk away.
#
# A few practical tips make QR codes work. Add a one-line label under the code so the reader knows what they are scanning ("Scan for the live dashboard" beats a bare square). Use any free QR generator, keep the link short and stable, and test the printed code with two or three different phones before you submit. And treat the code as a bonus, not a crutch: the poster still has to tell the whole story on its own, because most readers will never scan it.
#
# > **A question that often comes up here:** *"what should my QR code point to?"* Pick the one destination that rewards a curious reader the most. If your team built an interactive dashboard or an app, link there, because it lets the reader play with your model instead of only reading about it. If you did not build a live tool, link to your code repository, a two-minute video, or your team's LinkedIn pages for networking. Just avoid dropping people onto a raw, unlabeled file: whatever loads on their phone should look as polished as the poster that sent them there.

# %% [markdown]
# ---

# %% [markdown]
# ## 17. Results and Interpretation
#
# This is the section judges study the longest, so make it easy on them. Show three things, in this order.
#
# First, the **headline number**: the single metric that says whether your model is actually useful.
#
# Second, the **comparison** that proves the number is real and not luck. This is almost always your model shown next to a simple baseline, with both confidence intervals so the reader can see the gap is solid.
#
# Third, a **diagnostic** that shows you took the result seriously: a calibration plot, a fairness check across groups, an error breakdown by segment, or a confusion matrix with one cell highlighted.
#
# That is the whole Results block: three figures, one short paragraph each. The temptation is to show every metric from every notebook, but that buries the reader. Pick the three figures that tell the clearest story, and let the rest stay in your analysis notebook.

# %% [markdown]
# **Showing the performance.** The clearest pattern is a side-by-side or grouped-bar comparison. For a classification project, use a confusion matrix and highlight the cell your stakeholder cares about most: usually the false negatives when missing a real case is expensive (medical screening, fraud detection), or the false positives when a false alarm is expensive (spam filters, loan approvals). For a regression project, use an actual-versus-predicted scatter plot, or a bar chart of errors broken out by group. In every case, place your model right next to the baseline from notebook 09 (the dummy classifier, or the mean-only predictor) on the same figure, so the judge sees the improvement at a glance.
#
# **Showing your thinking.** Judges reward this more than most teams expect. They want to see that you can explain *why* the model behaved the way it did, not just report a score. Which features mattered most? Where does the model struggle, and for which customers or cases? What would you fix with more data, more time, or a different method? Naming your model's weak spot is not a confession; it is a credibility builder. The team that hides its worst-performing segment is exactly the team a sharp judge catches.

# %% [markdown]
# **The pattern in one line: show the confidence interval, name the baseline, label the failure mode.** The confusion matrix with one cell highlighted tells the cost story. The comparison bar chart against the baseline tells the "is this real?" story. The calibration plot, fairness check, or segment breakdown tells the "where does it fail?" story. Three figures, a few sentences each, and the honesty is what makes the whole thing believable.
#
# > **A question that often comes up here:** *"should I put the confusion matrix or the ROC curve on the poster?"* For a classification project, lead with the confusion matrix and highlight one cell (false negatives or false positives, depending on which mistake costs your stakeholder more). The confusion matrix tells a cost story anyone can read, while the ROC curve tells a threshold story that takes training to interpret, so it rarely earns its space on a poster. For a regression project, show the actual-versus-predicted scatter or the residual plot, whichever makes the "where does the model miss?" story clearest.

# %% [markdown]
# ---

# %% [markdown]
# ## 18. Conclusion and Future Work
#
# The two short paragraphs at the bottom of the poster carry more weight than their size suggests. The **Conclusion** is the line a reader repeats to a colleague the next day, so it has to be concrete and memorable. **Future Work** is the line that shows your team can see past the assignment to the next step. Both are short, roughly 50 words each, and both deserve more editing than anything else on the poster.

# %% [markdown]
# **A strong Conclusion does three things in three sentences.** It restates the main finding in plain words a non-expert can repeat ("the model flags the riskiest 10% of accounts with 87% recall"). It names the real-world payoff ("that gives the outreach team a three-week head start before renewals close"). And it says how sure you are ("the 95% cross-validation interval of 0.84 to 0.90 says this is not a lucky split"). Set that against a weak conclusion like "the model performs well," which is true, forgettable, and useless to the stakeholder.
#
# **A strong Future Work section names specific next steps, not wishes.** "Adding lag features to capture seasonal demand (see notebook 16) would help the model anticipate spikes" is concrete and credible. "A more robust model could be built" is filler that signals you ran out of ideas. The best future-work items come straight from limitations you already found: a weak segment from your error analysis, a data-quality gap from your EDA, or a population shift your monitoring plan would catch.

# %% [markdown]
# **The test for both paragraphs: specific beats vague, every time.** "The model performs well" is forgettable. "The calibrated model supports a screening cutoff of 0.42, catching 85% of true cases at a 5-to-1 cost ratio" is a line a reader can carry into their next meeting. Spend more time on these two paragraphs than on any equation on the poster, because they are what a busy reader actually remembers.
#
# > **A question that often comes up here:** *"how do I write the conclusion if my final numbers might still change?"* Draft it now anyway. The shape of the sentence (finding, then payoff, then confidence level) does not change even if a metric shifts by a point or two once your champion model is locked. Swapping in the final number takes thirty seconds; writing a clear paragraph from scratch on submission night takes an hour you will not have.

# %% [markdown]
# ---

# %% [markdown]
# ## 19. Final Touches
#
# Acknowledgments, references, and proofreading are not afterthoughts; they are free rubric points. Judges check your reference list to confirm you credited the tools you used (`scikit-learn`, `pandas`, `statsmodels`), your data source, and the course materials behind your method. A missing citation or a typo in the title is a small mistake, and a small mistake is the easiest kind to prevent.

# %% [markdown]
# **Acknowledgments and references are scored.** List the libraries you relied on (`scikit-learn`, `pandas`, `statsmodels`), your data source, and the textbook or course materials that shaped your method. Pick one citation format and stick to it (APA is fine for this course). Thank the faculty, teammates, and any funding source that helped along the way.
#
# **Proofreading and rehearsal are where the last few points hide.** Spell-check every block of text. Check every number against your notebook: a poster that says "ROC-AUC = 0.87" when your notebook says 0.85 quietly undermines the whole project. Make sure every image is sharp at print size, because a blurry confusion matrix blown up to poster scale looks worse than no figure at all. Then practice out loud on a non-expert, such as a roommate, a parent, or anyone outside the course. If they cannot repeat your main conclusion in one sentence, the poster is not finished yet.

# %% [markdown]
# **The rehearsal is the highest-value step in this whole list.** Print a draft poster at full size, tape it to a wall, stand three feet back, and time how long it takes a teammate who did not build the project to find your headline number. If they cannot find it in 30 seconds, the layout has buried it, and no amount of proofreading will fix that. Do this at least 48 hours before the deadline, so you have time to redesign rather than just retype.

# %% [markdown]
# ---

# %% [markdown]
# ## 20. Presenting Your Poster (Optional for the Summer Course)
#
# If your group elects to present at the Undergraduate Research Conference, the poster is half the work; the live presentation is the other half. The two demand different skills: the poster is a self-standing document that works when nobody is there; the presentation is a guided tour with a human voice. Tips below come from past course teams who have presented at URC; the advice is concrete because it comes from real experience, not from a textbook.

# %% [markdown]
# The mechanics of a good poster presentation reduce to a few high-leverage habits:
#
# - **Prepare three pitches ahead**: **30-second, 90-second, 2-minute**. Use the poster as the visual guide for each. The 30-second version is a single sentence: "We built a model that predicts X with Y% accuracy, and the business implication is Z." The 90-second version adds the method and the key limitation. The 2-minute version walks the poster top to bottom.
# - **Prepare questions**: open with *"Are you familiar with...?"*. Actively ask questions of your audience to keep it a conversation.
# - **Arrive early** to set up; board assignments shift sometimes.
# - **Stay close** to your poster, off to the side. Do not block the figures.
# - **Use your hands** to direct the listener's eye to specific sections of the poster.
# - Do not let one teammate dominate; rotate naturally.
# - [**Follow the dress code: business professional**](https://www.purdue.edu/undergrad-research/conferences/fall/photo-gallery.php). [CCO Career Closet](https://www.cco.purdue.edu/Students/WhatWeOffer?tab=CareerCloset) can help if you need it.

# %% [markdown]
# ---

# %% [markdown]
# ## 📝 PAUSE-AND-DO Exercise 2: Outline Your Poster + Draft the Abstract (15 minutes)
#
# **Task:** Draft the **eleven-section outline** for your group's poster, plus a one-paragraph **abstract**. This is the single highest-leverage piece of work you can do today: the abstract is the most-read paragraph on the poster, and the section outline locks the layout for the rest of Milestone 04.
#
# **Instructions:**
#
# 1. Fill the **Section Outline** table below, one to two sentences per row, in your own words. Where a section does not yet have an answer, write *"TBD: assign a teammate's initials"* and assign a teammate's initials.
# 2. Below the table, draft the **abstract** as a single paragraph of **120–150 words**. Cover, in order:
#    - The problem (one sentence)
#    - The data and target (one sentence)
#    - The modeling approach (one sentence)
#    - The headline result with 95% CI (one sentence)
#    - The business implication (one sentence)
# 3. Read the abstract aloud. If a sentence has more than thirty words, split it.
#
# ---
#
# > 💡 **Gemini Prompt:** "I'm drafting the abstract paragraph for a research-conference poster on a predictive-analytics project. The project is about [problem]. The dataset is [data + target]. The modeling approach is [approach]. The headline result is [metric + value + 95% CI]. The business implication is [decision the model supports]. Draft a 120–150-word abstract that follows this five-sentence structure, prioritises clarity over jargon, and ends on the business implication. Then list three sentences I should consider cutting and explain why."
# >
# > **After running, verify:**
# > - [ ] Abstract is 120–150 words (count them; Gemini drifts long)
# > - [ ] First sentence states the **problem**, not the model
# > - [ ] Last sentence states the **decision the model supports**, not a metric
# > - [ ] No jargon a Purdue undergrad outside Daniels would not understand
#
# ---

# %%
This predictive-analytics project addresses the critical challenge of accurately forecasting mass layoffs in companies, aiming to enable more proactive organizational stability and planning. Our research leveraged a comprehensive dataset, including historical company financial performance, employee metrics, and broader macroeconomic indicators, with the `layoff_rate_pct` serving as the crucial target variable. We employed a Gradient Boosting Machine (GBM) modeling approach, chosen for its superior ability to capture complex non-linear relationships and deliver high predictive accuracy. The developed model demonstrated robust performance, achieving an impressive ROC-AUC of 0.85 (95% CI: 0.82-0.88) in identifying companies with a high risk of layoffs within the subsequent quarter. This precise predictive capability provides a vital tool for corporate strategists, enabling them to implement early intervention and mitigation strategies, thereby safeguarding employee well-being and fostering enhanced long-term business resilience.

### Sentences to Consider Cutting:

1.  **"aiming to enable more proactive organizational stability and planning."**
    *   **Explanation:** While this clarifies the problem's objective, the core problem is already established by "accurately forecasting mass layoffs." This phrase elaborates on the benefits, which are also detailed in the final business implication sentence, making it somewhat redundant for an extremely concise abstract.

2.  **"including historical company financial performance, employee metrics, and broader macroeconomic indicators"**
    *   **Explanation:** This part provides specific details about the dataset's features. For an abstract, simply stating that a "comprehensive dataset" was leveraged, with the target variable, is often sufficient. The specific components can be elaborated in the Data and EDA sections of the poster.

3.  **"chosen for its superior ability to capture complex non-linear relationships and deliver high predictive accuracy."**
    *   **Explanation:** This clause explains the rationale behind selecting the Gradient Boosting Machine. While important, for an abstract focused on brevity, identifying the modeling approach ("Gradient Boosting Machine (GBM)") is the essential information, and the justification can be expanded upon in the Methodology section of your poster.

# %% [markdown]
# ### YOUR FINDINGS HERE:
#
# **Section Outline:**
#
# | # | Section | Draft (1–2 sentences) |
# |---|---|---|
# | 1 | Title and Authors | Predicting Mass Layoffs: A Machine Learning Approach for Proactive Organizational Stability. By Group 3, Rishi Vira, Gracyn Erickson, Eduardo Luna Lopez, and Zhijun Zhou. |
# | 2 | Abstract / Introduction | _(This predictive-analytics project addresses the critical challenge of accurately forecasting mass layoffs in companies, aiming to enable more proactive organizational stability and planning. Our research leveraged a comprehensive dataset, including historical company financial performance, employee metrics, and broader macroeconomic indicators, with the `layoff_rate_pct` serving as the crucial target variable. We employed a Gradient Boosting Machine (GBM) modeling approach, chosen for its superior ability to capture complex non-linear relationships and deliver high predictive accuracy. The developed model demonstrated robust performance, achieving an impressive ROC-AUC of 0.85 (95% CI: 0.82-0.88) in identifying companies with a high risk of layoffs within the subsequent quarter. This precise predictive capability provides a vital tool for corporate strategists, enabling them to implement early intervention and mitigation strategies, thereby safeguarding employee well-being and fostering enhanced long-term business resilience.)_ |
# | 3 | Business Problem | Mass layoffs pose significant economic and social challenges for companies and their employees. This project aims to develop a predictive model to identify companies at high risk of initiating mass layoffs. |
# | 4 | Analytics Problem Framing | We framed the business problem as a binary classification task: predicting the likelihood of a company experiencing a mass layoff event based on a composite `layoff_rate_pct` target variable. This allows for early identification of at-risk entities. |
# | 5 | Research Question | Can machine learning models accurately predict the probability of mass layoffs in companies using a combination of financial, employment, and macroeconomic indicators? |
# | 6 | Data and EDA | Our dataset comprises historical company data, including financial metrics, employee counts, hiring rates, and relevant macroeconomic indices. Exploratory Data Analysis (EDA) focused on understanding variable distributions and initial correlations with the `layoff_rate_pct`. |
# | 7 | Methodology | A Gradient Boosting Machine (GBM) was selected for its robustness and ability to handle diverse feature types, utilizing a leakage-safe pipeline to prevent data contamination. Cross-validation was employed to ensure model generalization. |
# | 8 | Model Building and Evaluation | The GBM model was trained and rigorously evaluated using a locked test set, demonstrating a ROC-AUC of 0.85 (95% CI: 0.82-0.88). Performance metrics, including precision and recall, were also assessed to confirm predictive utility. |
# | 9 | Business Implication | This predictive model provides corporate strategists with an early warning system, enabling the implementation of proactive measures such as workforce retraining or financial restructuring to mitigate the impact of potential layoffs. It supports informed decision-making to foster greater organizational resilience and employee stability. |
# | 10 | Conclusion and Future Work | Our model successfully predicts mass layoffs with high accuracy, offering a valuable tool for strategic planning. Future work will explore incorporating real-time sentiment analysis from company news and social media to further enhance predictive power. |
# | 11 | Acknowledgments and References | We acknowledge Professor Davi Moreira for guidance and support, and thank the course staff for their assistance. References include `scikit-learn`, `pandas`, and other relevant academic sources. |
#
# **Abstract (120–150 words):**
#
# _(This predictive-analytics project addresses the critical challenge of accurately forecasting mass layoffs in companies, aiming to enable more proactive organizational stability and planning. Our research leveraged a comprehensive dataset, including historical company financial performance, employee metrics, and broader macroeconomic indicators, with the `layoff_rate_pct` serving as the crucial target variable. We employed a Gradient Boosting Machine (GBM) modeling approach, chosen for its superior ability to capture complex non-linear relationships and deliver high predictive accuracy. The developed model demonstrated robust performance, achieving an impressive ROC-AUC of 0.85 (95% CI: 0.82-0.88) in identifying companies with a high risk of layoffs within the subsequent quarter. This precise predictive capability provides a vital tool for corporate strategists, enabling them to implement early intervention and mitigation strategies, thereby safeguarding employee well-being and fostering enhanced long-term business resilience.)_
#
# ---

# %% [markdown]
# ## 21. Additional Material
#
# The four resources below are the ones I most often recommend to teams sharpening their poster figures in the final week. None are required reading, but each one will repay an hour.
#
# - **[Flowing Data](https://flowingdata.com/)**: Nathan Yau's blog on the design of practical, journalistic data graphics.
# - **[Information Is Beautiful](https://informationisbeautiful.net/blog/)**: David McCandless's portfolio of design-led information graphics; useful for color-palette and layout inspiration.
# - **[The Functional Art](http://www.thefunctionalart.com/)**: Alberto Cairo on the discipline of journalistic chart design.
# - **[COVID in the Financial Times](https://www.ft.com/content/a2901ce8-5eb7-4633-b89c-cbdf5b386938)**: John Burn-Murdoch's pandemic charting work; a master class in hierarchy and annotation under deadline pressure.
#
# ---

# %% [markdown]
# ## 22. Wrap-Up: Key Takeaways
#
# **The Six Principles you can audit any chart against:**
#
# 1. **Context Matters**: every number needs a baseline.
# 2. **Visualization Derives From Data**: the data shape picks the chart, not the other way around.
# 3. **Less Is More**: high data-ink ratio beats decorative ink, every time.
# 4. **Hierarchy**: the eye is not democratic; choose what wins it.
# 5. **Beauty Counts**: pleasant charts retain readers long enough to deliver the message.
# 6. **Telling Your Story**: every figure should pass the cover-and-restate test.
#
# **The Eleven Poster Sections you can plan against:**
#
# Title → Abstract → Business Problem → Analytics Framing → Research Question → Data/EDA → Methodology → Model Building → Business Implication → Conclusion → Acknowledgments.
#
# **One sentence to take into the final-poster sprint:**
#
# > *“Cover up your favorite figure. If a stranger cannot restate the conclusion in one sentence, the figure is not yet ready.”*
#
# ### Bridge to Notebook 18
#
# Notebook 18 wraps your champion model into a **competition workflow**: a production-grade pipeline that reads raw data, preprocesses, predicts, and writes a `submission.csv` for the class leaderboard. Bring the audited figure from Exercise 1 and the abstract from Exercise 2 with you; they feed directly into the poster you will finalize over the final days. After nb18, notebook 19 introduces deep learning as a horizon topic, and notebook 20 closes the course with the peer-review and postmortem workflow.
#
# > **A question that often comes up at this point:** *“how much polish does the final poster really need?”* The honest answer: more than feels reasonable, less than feels infinite. Plan for **two complete rebuilds** of your headline figure and **three drafts** of your abstract. Stop when a non-specialist outside the course can read the poster top-to-bottom in ninety seconds and restate the result in one sentence. That is the test. That is also the standard the URC judges apply.
#
# ---

# %% [markdown]
# ## Participation Assignment Submission Instructions
#
# ### To Submit This Notebook:
#
# 1. **Complete both PAUSE-AND-DO exercises**: Exercise 1 (figure audit) and Exercise 2 (poster outline + abstract).
# 2. **Run All Cells**: `Runtime → Run all` to ensure every cell executes without error.
# 3. **Save a Copy**: `File → Save a copy in Drive`, or download as `.ipynb`.
# 4. **Submit**: upload the `.ipynb` file to the Notebook 17 participation assignment on Brightspace.
#
# ### Before Submitting, Check:
#
# - [ ] Both exercise responses are complete (no `_(your draft)_` placeholders remaining)
# - [ ] All figures render (none broken)
# - [ ] Notebook executes without errors
# - [ ] You can defend every design choice in your poster outline if a teammate asks why
#
# ### Next Step:
#
# - **Notebook 18**: Competition workflow + Kaggle submission (Day 18)
#
# ---
#
# <center>
#
# **Thank you!**
#
# </center>
